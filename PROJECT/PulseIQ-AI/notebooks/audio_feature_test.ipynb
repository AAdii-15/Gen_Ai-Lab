# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from feature_extraction.audio_features import extract_features

# %%
features = extract_features("/Users/aadiii/Desktop/PulseIQ-AI/data/audio_samples/test_voice.wav")

features
# Out:
# {'pitch': np.float32(808.33685),
#  'spectral_centroid': np.float64(2750.939476724166),
#  'zcr': np.float64(0.05880551926845199),
#  'mfcc_1': np.float32(-435.868),
#  'mfcc_2': np.float32(129.61429),
#  'mfcc_3': np.float32(11.928988),
#  'mfcc_4': np.float32(45.84624),
#  'mfcc_5': np.float32(9.004172),
#  'mfcc_6': np.float32(29.492626),
#  'mfcc_7': np.float32(-5.65464),
#  'mfcc_8': np.float32(6.109964),
#  'mfcc_9': np.float32(-3.8920283),
#  'mfcc_10': np.float32(-10.82201),
#  'mfcc_11': np.float32(7.8525887),
#  'mfcc_12': np.float32(-8.14922),
#  'mfcc_13': np.float32(-1.1143491)}

# %%
import pandas as pd

df_features = pd.DataFrame([features])

df_features
# Out:
#         pitch  spectral_centroid       zcr      mfcc_1      mfcc_2     mfcc_3  \
# 0  808.336853        2750.939477  0.058806 -435.868011  129.614288  11.928988
#
#       mfcc_4    mfcc_5     mfcc_6   mfcc_7    mfcc_8    mfcc_9   mfcc_10  \
# 0  45.846241  9.004172  29.492626 -5.65464  6.109964 -3.892028 -10.82201
#
#     mfcc_11  mfcc_12   mfcc_13
# 0  7.852589 -8.14922 -1.114349

# %%
df_features.columns
# Out:
# Index(['pitch', 'spectral_centroid', 'zcr', 'mfcc_1', 'mfcc_2', 'mfcc_3',
#        'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10',
#        'mfcc_11', 'mfcc_12', 'mfcc_13'],
#       dtype='str')

# %%
df_features.to_csv("../data/processed/sample_voice_features.csv", index=False)
